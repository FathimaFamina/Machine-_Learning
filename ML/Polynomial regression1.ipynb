# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data (replace with your actual data)
data = {
    'Id': [1, 2, 3, 4, 5],
    'Confirmed': [10, 15, 20, 25, 30]
}

# Convert data to numpy arrays
x = np.array(data['Id']).reshape(-1, 1)
y = np.array(data['Confirmed']).reshape(-1, 1)

# Plot with matplotlib
plt.plot(x,y, '-m')  # Plot y with a solid magenta line
plt.xlabel('Index')
plt.ylabel('Confirmed Cases')
plt.title('Confirmed Cases over Index')

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

# %%
###Step-1:LOAD DATA ####
data = pd.read_csv(r'C:\Users\USER\Downloads\Polynomial regression\coronaCases.csv',sep =',')
data = data[['Id','Confirmed']]
data.head(5)
# Out:
#    Id  Confirmed
# 0   1       6334
# 1   2       6753
# 2   3       6960
# 3   4       6036
# 4   5       3361

# %%
x = np.array(data['Id']).reshape(-1, 1)
y = np.array(data['Confirmed']).reshape(-1, 1)
plt.plot(y,'-m')
polyFeat = PolynomialFeatures(degree=2)
x = polyFeat.fit_transform(x)
x
# Out:
# array([[1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00],
#        [1.000e+00, 3.000e+00, 9.000e+00],
#        [1.000e+00, 4.000e+00, 1.600e+01],
#        [1.000e+00, 5.000e+00, 2.500e+01],
#        [1.000e+00, 6.000e+00, 3.600e+01],
#        [1.000e+00, 7.000e+00, 4.900e+01],
#        [1.000e+00, 8.000e+00, 6.400e+01],
#        [1.000e+00, 9.000e+00, 8.100e+01],
#        [1.000e+00, 1.000e+01, 1.000e+02],
#        [1.000e+00, 1.100e+01, 1.210e+02],
#        [1.000e+00, 1.200e+01, 1.440e+02],
#        [1.000e+00, 1.300e+01, 1.690e+02],
#        [1.000e+00, 1.400e+01, 1.960e+02],
#        [1.000e+00, 1.500e+01, 2.250e+02],
#        [1.000e+00, 1.600e+01, 2.560e+02],
#        [1.000e+00, 1.700e+01, 2.890e+02],
#        [1.000e+00, 1.800e+01, 3.240e+02],
#        [1.000e+00, 1.900e+01, 3.610e+02],
#        [1.000e+00, 2.000e+01, 4.000e+02],
#        [1.000e+00, 2.100e+01, 4.410e+02],
#        [1.000e+00, 2.200e+01, 4.840e+02],
# ...

# %%
model = linear_model.LinearRegression()
model.fit(x,y)
accuracy = model.score(x,y)
print(f'Accuracy:{round(accuracy*100,3)} %')
y0 = model.predict(x)
plt.plot(y0,'--b')
plt.plot(y,'-m')
plt.show()
# Out:
# Accuracy:75.284 %

# %%
Add_days = 10
cur_day= y.shape[0]
pred_day =cur_day+Add_days
X_poly_fit=polyFeat.fit_transform([[pred_day]])
y_pred =model.predict(X_poly_fit)
print('-'*20);print('PREDICTION');print('-'*20)
print(f'Prediction - Cases after {Add_days} days:',end='')
print(round(int(y_pred)/1000,2),'Thousdands')
# Out:
# --------------------
# PREDICTION
# --------------------
# Prediction - Cases after 10 days:15.98 Thousdands

# %%
x1 = np.array(list(range(1,pred_day))).reshape(-1,1)
y1 = model.predict(polyFeat.fit_transform(x1))
plt.plot(y1,'--r')
plt.plot(y0,'--b')
plt.plot(y,'-g')
plt.show()

# %%
data = pd.read_csv(r'C:\Users\USER\Downloads\Polynomial regression\Kerala_COVID-19 Statistics-full.csv',sep =',')

data.head(5)
# Out:
#         Date  Confirmed  Recovered  Active  Death
# 0  1/30/2020          1          0       1      0
# 1   2/2/2020          1          0       2      0
# 2   2/3/2020          1          0       3      0
# 3  2/16/2020          0          2       1      0
# 4  2/16/2020          0          1       0      0

# %%
import pandas as pd

# Read the CSV file into a DataFrame
file_path = r'C:\Users\USER\Downloads\Polynomial regression\Kerala_COVID-19 Statistics-full.csv'
data = pd.read_csv(file_path, sep=',')

# Convert 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Filter data for January
january_data = data[data['Date'].dt.month == 9]

# Display filtered data
print(january_data)
# Out:
#           Date  Confirmed  Recovered  Active  Death
# 5   2020-09-03          6          0       6      0
# 177 2020-09-01       1140       2111   22512      4
# 178 2020-09-02       1547       2129   21923      7
# 179 2020-09-03       1553       1950   21516     10
# 180 2020-09-04       2479       2716   21268     11
# 181 2020-09-05       2655       2111   21800     11
# 182 2020-09-06       3082       2196   22676     10
# 183 2020-09-07       1648       2246   22066     12
# 184 2020-09-08       3026       1862   23217     13
# 185 2020-09-09       3402       2058   24549     12
# 186 2020-09-10       3349       1657   26229     12
# 187 2020-09-11       2988       1326   27877     14
# 188 2020-09-12       2885       1944   28802     15
# 189 2020-09-13       3139       1855   30072     14
# 190 2020-09-14       2540       2110   30486     15
# 191 2020-09-15       3215       2532   31156     12
# 192 2020-09-16       3830       2263   32710     13
# ...
